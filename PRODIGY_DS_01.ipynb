# %%
pip install pandas matplotlib seaborn

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/API_SP.POP.TOTL_DS2_en_csv_v2_38144.csv', delimiter=',', encoding='utf-8', skiprows=4)
df.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54922.0      55578.0      56320.0      57002.0      57619.0
# 1  130075728.0  133534923.0  137171659.0  140945536.0  144904094.0
# 2    9035043.0    9214083.0    9404406.0    9604487.0    9814318.0
# 3   97630925.0   99706674.0  101854756.0  104089175.0  106388440.0
# 4    5231654.0    5301583.0    5354310.0    5408320.0    5464187.0
#
#           1965  ...         2016         2017         2018         2019  \
# ...

# %%
df.columns = df.columns.str.strip()
print(df.columns)
# Out:
# Index(['Data Source,"World Development Indicators",'], dtype='object')

# %%
year_columns = [col for col in df.columns if col.isdigit()]

# %%
country_name = "India"
country_data = df[df['Country Name'] == country_name]

if not country_data.empty:
    population = country_data[year_columns].values.flatten()

    plt.figure(figsize=(10, 5))
    plt.bar(year_columns, population, color='skyblue')
    plt.title(f"{country_name} Population Over the Years")
    plt.xlabel("Year")
    plt.ylabel("Population")
    plt.xticks(ticks=range(0, len(year_columns), 5), labels=[year_columns[i] for i in range(0, len(year_columns), 5)], rotation=45)
    plt.tight_layout()
    plt.show()

# %%
if not country_data.empty:
    population = country_data[year_columns].values.flatten()

    plt.figure(figsize=(10, 5))
    plt.bar(year_columns, population, color='skyblue')
    plt.title(f"{country_name} Population Over the Years")
    plt.xlabel("Year")
    plt.ylabel("Population")
    plt.xticks(ticks=range(0, len(year_columns), 5), labels=[year_columns[i] for i in range(0, len(year_columns), 5)], rotation=45)
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(8, 4))
    plt.hist(population, bins=10, color='orange', edgecolor='black')
    plt.title(f"{country_name} Population Histogram")
    plt.xlabel("Population")
    plt.ylabel("Frequency")
    plt.tight_layout()
    plt.show()
else:
    print(f"Country '{country_name}' not found in dataset.")
